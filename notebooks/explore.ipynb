# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import plotly.express as px
import glob, os
import seaborn as sns

# %%
user_list = glob.glob('../data/Archived users/*.txt')

user_data = []

for user in user_list:
    user_dict = {}
    id = user.split('_')[1].split('.')[0]
    user_dict['id'] = id
    with open(user) as f:
        lines = f.readlines()
        for line in lines:
            line = line.strip()
            key = line.split(': ')[0]
            val = np.nan if len(line.split(': ')) == 1 else line.split(': ')[1]
            user_dict[key] = val
        user_data.append(user_dict)

user_data = pd.DataFrame(user_data)

# %%
user_data=user_data.drop(columns=[col for col in user_data.columns if ':' in col])
user_data.head()
# Out:
#            id BirthYear  Gender Parkinsons Tremors DiagnosisYear Sided  \
# 0  0EA27ICBLF      1952  Female       True    True          2000  Left
# 1  0QAZFRHQHW      1959  Female      False   False        ------  None
# 2  0WTDIGPSBZ      1946  Female      False   False        ------  None
# 3  1HOEBIGASW      1944    Male      False   False        ------  None
# 4  1WMVCCU4RH      1953    Male       True    True          2017  Left
#
#         UPDRS   Impact Levadopa     DA   MAOB  Other
# 0  Don't know   Severe     True   True  False  False
# 1  Don't know   ------    False  False  False  False
# 2  Don't know   ------    False  False  False  False
# 3  Don't know   ------    False  False  False  False
# 4  Don't know   Medium    False  False  False  False

# %%
def is_medicated(df):
    return df['Levadopa'] or df['MAOB'] or df['Other'] or df['DA']

user_data['Age'] = 2017 - user_data['BirthYear'].astype(float)
user_data['Medicated'] = user_data.apply(is_medicated, axis=1)

#convert to numeric, fill NaN with 0
user_data['DiagnosisYear'] = pd.to_numeric(user_data['DiagnosisYear'], errors='coerce')
user_data['DiagnosisYear'].fillna(0, inplace=True)
user_data['SinceDiagnosis'] = 2017 - user_data['DiagnosisYear'].astype(float)
user_data.head()
# Out:
#            id BirthYear  Gender Parkinsons Tremors  DiagnosisYear Sided  \
# 0  0EA27ICBLF      1952  Female       True    True         2000.0  Left
# 1  0QAZFRHQHW      1959  Female      False   False            0.0  None
# 2  0WTDIGPSBZ      1946  Female      False   False            0.0  None
# 3  1HOEBIGASW      1944    Male      False   False            0.0  None
# 4  1WMVCCU4RH      1953    Male       True    True         2017.0  Left
#
#         UPDRS   Impact Levadopa     DA   MAOB  Other   Age Medicated  \
# 0  Don't know   Severe     True   True  False  False  65.0      True
# 1  Don't know   ------    False  False  False  False  58.0     False
# 2  Don't know   ------    False  False  False  False  71.0     False
# 3  Don't know   ------    False  False  False  False  73.0     False
# 4  Don't know   Medium    False  False  False  False  64.0     False
#
#    SinceDiagnosis
# 0            17.0
# 1          2017.0
# 2          2017.0
# 3          2017.0
# 4             0.0

# %%
user_data['Parkinsons'] = user_data['Parkinsons'] == 'True'
user_data['Tremors'] = user_data['Tremors'] == 'True'
user_data['Medicated'] = user_data['Medicated'] == 'True'
cols = ['id', 'Age', 'Gender', 'Parkinsons', 'Tremors', 'SinceDiagnosis', 'Sided', 'UPDRS', 'Impact', 'Levadopa', 'DA', 'MAOB', 'Other', 'Medicated']
user_data = user_data[cols]
user_data.head()
# Out:
#            id   Age  Gender  Parkinsons  Tremors  SinceDiagnosis Sided  \
# 0  0EA27ICBLF  65.0  Female        True     True            17.0  Left
# 1  0QAZFRHQHW  58.0  Female       False    False          2017.0  None
# 2  0WTDIGPSBZ  71.0  Female       False    False          2017.0  None
# 3  1HOEBIGASW  73.0    Male       False    False          2017.0  None
# 4  1WMVCCU4RH  64.0    Male        True     True             0.0  Left
#
#         UPDRS   Impact Levadopa     DA   MAOB  Other  Medicated
# 0  Don't know   Severe     True   True  False  False       True
# 1  Don't know   ------    False  False  False  False      False
# 2  Don't know   ------    False  False  False  False      False
# 3  Don't know   ------    False  False  False  False      False
# 4  Don't know   Medium    False  False  False  False      False

# %%
# Apply the transformation to the 'UPDRS' column
user_data['UPDRS'] = user_data['UPDRS'].apply(lambda x: int(x) if x != 'Don\'t know' else 0)

# Define the impact dictionary
impact_dict = {'Mild': 1, 'Medium': 2, 'Severe': 3, ' ------': 0, np.nan: 0}

# Apply the transformation to the 'Impact' column
user_data['Impact'] = user_data['Impact'].apply(lambda x: impact_dict[x]).fillna(0)

user_data.head()
# Out:
#            id   Age  Gender  Parkinsons  Tremors  SinceDiagnosis Sided  UPDRS  \
# 0  0EA27ICBLF  65.0  Female        True     True            17.0  Left      0
# 1  0QAZFRHQHW  58.0  Female       False    False          2017.0  None      0
# 2  0WTDIGPSBZ  71.0  Female       False    False          2017.0  None      0
# 3  1HOEBIGASW  73.0    Male       False    False          2017.0  None      0
# 4  1WMVCCU4RH  64.0    Male        True     True             0.0  Left      0
#
#    Impact Levadopa     DA   MAOB  Other  Medicated
# 0       3     True   True  False  False       True
# 1       0    False  False  False  False      False
# 2       0    False  False  False  False      False
# 3       0    False  False  False  False      False
# 4       2    False  False  False  False      False

# %%
user_data.to_csv('user_data.csv', index=False)

# %%
data_list = glob.glob('Tappy Data/*.txt')
exp_data = []
for data in data_list:
    with open(data) as f:
        lines = f.readlines()
        for line in lines:
            line = line.strip().split('\t')
            if len(line) != 8:
                print(line)
            else:
                exp_data.append(line)
# Out:
# ['OMCPRWYBSQ', '161027', '11:38:01.707', 'R', '0085.9', 'LR', '0601.6']
# ['QAH9IVALVC', '160829', '13:33:10.324', 'L', '0078.1', 'LL', '0250.0']

# %%
exp_data = pd.DataFrame(exp_data, columns=['id','date','time','hand', 'hold_time', 'direction', 'latency', 'flight_time'])
display(exp_data)
# Out:
#                  id    date          time hand hold_time direction latency  \
# 0        0EA27ICBLF  160722  18:41:04.336    L    0101.6        LL  0234.4
# 1        0EA27ICBLF  160722  18:42:14.070    L    0085.9        LL  0437.5
# 2        0EA27ICBLF  160722  18:42:14.273    L    0078.1        LL  0210.9
# 3        0EA27ICBLF  160722  18:42:14.617    L    0062.5        LL  0359.4
# 4        0EA27ICBLF  160722  18:42:15.586    S    0125.0        LS  0187.5
# ...             ...     ...           ...  ...       ...       ...     ...
# 9316851  ZYWLN4JVLA  170126  13:56:20.117    L    0195.3        RL  0425.8
# 9316852  ZYWLN4JVLA  170126  13:56:20.242    R    0105.5        LR  0214.8
# 9316853  ZYWLN4JVLA  170126  13:56:33.625    L    0168.0        LL  0332.0
# 9316854  ZYWLN4JVLA  170126  13:56:33.836    L    0097.7        LL  0281.3
# 9316855  ZYWLN4JVLA  170126  13:56:34.066    L    0168.0        LL  0160.2
#
#         flight_time
# 0            0156.3
# 1            0359.4
# 2            0125.0
# 3            0281.3
# 4            0093.8
# ...             ...
# 9316851      0261.7
# 9316852      0019.5
# 9316853      0015.6
# 9316854      0113.3
# 9316855      0062.5
#
# [9316856 rows x 8 columns]

# %%
def process_rows(df):
    if len(df['id']) != 10:
        df['id'] = np.nan
    if len(df['hold_time']) != 6:
        df['hold_time'] = np.nan
    else:
        df['hold_time'] = float(df['hold_time'])

    if len(df['latency']) != 6:
        df['latency'] = np.nan
    else:
        df['latency'] = float(df['latency'])
    if len(df['flight_time']) != 6:
        df['flight_time'] = np.nan
    else:
        df['flight_time'] = float(df['flight_time'])
    return df

# %%
exp_data = exp_data.apply(process_rows, axis=1)

# %%
exp_data.head()
# Out:
#                  id    date          time hand  hold_time direction  latency  \
# 0        NMMGWRY6SO  170301  08:45:42.125    L      187.5        LL    421.9
# 1        NMMGWRY6SO  170301  08:45:42.422    L      203.1        LL    281.3
# 2        NMMGWRY6SO  170301  08:48:29.031    L      203.1        LL    296.9
# 3        NMMGWRY6SO  170301  08:48:29.266    L      218.8        LL    218.8
# 4        NMMGWRY6SO  170301  08:48:29.484    R      187.5        LR    250.0
# ...             ...     ...           ...  ...        ...       ...      ...
# 9316851  3HYXJCTCNT  170126  14:12:47.000    S       58.6        RS    214.8
# 9316852  3HYXJCTCNT  170126  14:12:49.422    R       85.9        LR    175.8
# 9316853  3HYXJCTCNT  170126  14:12:49.598    R       39.1        RR    222.7
# 9316854  3HYXJCTCNT  170126  14:12:51.160    L       43.0        LL    125.0
# 9316855  3HYXJCTCNT  170126  14:12:51.215    L       97.7        LL    125.0
#
#          flight_time
# 0              281.3
# 1               93.8
# 2              125.0
# 3               15.6
# 4               31.3
# ...              ...
# 9316851        160.2
# 9316852         82.0
# 9316853        136.7
# 9316854        285.2
# 9316855        285.2
#
# [9316856 rows x 8 columns]

# %%
exp_data = exp_data.dropna(axis=0)

# %%
exp_data.to_csv('typing_data.csv', index=False)
