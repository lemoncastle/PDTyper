# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import plotly.express as px
import glob, os
import seaborn as sns

# %%
user_list = glob.glob('Archived users/*.txt')

user_data = []

for user in user_list:
    user_dict = {}
    id = user.split('_')[1].split('.')[0]
    user_dict['id'] = id
    with open(user) as f:
        lines = f.readlines()
        for line in lines:
            line = line.strip()
            key = line.split(': ')[0]
            val = np.nan if len(line.split(': ')) == 1 else line.split(': ')[1]
            user_dict[key] = val
        user_data.append(user_dict)

# %%
user_data = pd.DataFrame(user_data)

# %%
user_data=user_data.drop(columns=[col for col in user_data.columns if ':' in col])
user_data
# Out:
#              id  Gender Parkinsons Tremors  Sided       UPDRS   Impact  \
# 0    PJU53Y7KVB    Male       True    True   Left  Don't know     Mild
# 1    G6OE5CXQPY    Male      False   False   None  Don't know   ------
# 2    2X17VCRRQA    Male       True    True   Left  Don't know   Severe
# 3    I3U47MF5UF  Female       True    True   None  Don't know   Medium
# 4    L7Q16SJ7KP    Male       True    True  Right  Don't know   Severe
# ..          ...     ...        ...     ...    ...         ...      ...
# 222  VIAXR21TSC  Female       True    True   Left  Don't know   Medium
# 223  IDZHIUK2W2  Female       True    True   None  Don't know     Mild
# 224  SW61HF6XRY    Male       True    True   None  Don't know   Severe
# 225  2JTCBKUP8T    Male       True    True  Right  Don't know   Medium
# 226  LSQWWDXEYO    Male       True    True   Left  Don't know     Mild
#
#     Levadopa     DA   MAOB  Other BirthYear DiagnosisYear
# 0       True  False  False  False       NaN           NaN
# 1      False  False  False  False      1952        ------
# 2       True  False  False  False      1951          2003
# 3       True  False  False   True      1947          2014
# 4       True  False   True  False      1965          2007
# ..       ...    ...    ...    ...       ...           ...
# 222     True  False  False   True      1946          2012
# 223     True  False  False  False      1943          2013
# 224     True  False  False   True      1953          2016
# 225     True  False  False  False      1958          2013
# 226    False   True  False  False      1951          2016
#
# [227 rows x 13 columns]

# %%
def is_medicated(df):
    return df['Levadopa'] or df['MAOB'] or df['Other'] or df['DA']

# %%
user_data['age'] = 2017 - user_data['BirthYear'].astype(float)
user_data['medicated'] = user_data.apply(is_medicated, axis=1)

# %%
user_data
# Out:
#              id  Gender Parkinsons Tremors  Sided       UPDRS   Impact  \
# 0    PJU53Y7KVB    Male       True    True   Left  Don't know     Mild
# 1    G6OE5CXQPY    Male      False   False   None  Don't know   ------
# 2    2X17VCRRQA    Male       True    True   Left  Don't know   Severe
# 3    I3U47MF5UF  Female       True    True   None  Don't know   Medium
# 4    L7Q16SJ7KP    Male       True    True  Right  Don't know   Severe
# ..          ...     ...        ...     ...    ...         ...      ...
# 222  VIAXR21TSC  Female       True    True   Left  Don't know   Medium
# 223  IDZHIUK2W2  Female       True    True   None  Don't know     Mild
# 224  SW61HF6XRY    Male       True    True   None  Don't know   Severe
# 225  2JTCBKUP8T    Male       True    True  Right  Don't know   Medium
# 226  LSQWWDXEYO    Male       True    True   Left  Don't know     Mild
#
#     Levadopa     DA   MAOB  Other BirthYear DiagnosisYear   age medicated
# 0       True  False  False  False       NaN           NaN   NaN      True
# 1      False  False  False  False      1952        ------  65.0     False
# 2       True  False  False  False      1951          2003  66.0      True
# 3       True  False  False   True      1947          2014  70.0      True
# 4       True  False   True  False      1965          2007  52.0      True
# ..       ...    ...    ...    ...       ...           ...   ...       ...
# 222     True  False  False   True      1946          2012  71.0      True
# 223     True  False  False  False      1943          2013  74.0      True
# 224     True  False  False   True      1953          2016  64.0      True
# 225     True  False  False  False      1958          2013  59.0      True
# 226    False   True  False  False      1951          2016  66.0     False
#
# [227 rows x 15 columns]

# %%
user_data['Parkinsons'] = user_data['Parkinsons'] == 'True'
user_data['Tremors'] = user_data['Tremors'] == 'True'
user_data['medicated'] = user_data['medicated'] == 'True'
cols = ['id', 'Gender', 'Parkinsons', 'Tremors', 'Sided', 'UPDRS', 'Impact', 'age', 'medicated']
user_data = user_data[cols]
user_data
# Out:
#              id  Gender  Parkinsons  Tremors  Sided       UPDRS   Impact  \
# 0    PJU53Y7KVB    Male        True     True   Left  Don't know     Mild
# 1    G6OE5CXQPY    Male       False    False   None  Don't know   ------
# 2    2X17VCRRQA    Male        True     True   Left  Don't know   Severe
# 3    I3U47MF5UF  Female        True     True   None  Don't know   Medium
# 4    L7Q16SJ7KP    Male        True     True  Right  Don't know   Severe
# ..          ...     ...         ...      ...    ...         ...      ...
# 222  VIAXR21TSC  Female        True     True   Left  Don't know   Medium
# 223  IDZHIUK2W2  Female        True     True   None  Don't know     Mild
# 224  SW61HF6XRY    Male        True     True   None  Don't know   Severe
# 225  2JTCBKUP8T    Male        True     True  Right  Don't know   Medium
# 226  LSQWWDXEYO    Male        True     True   Left  Don't know     Mild
#
#       age  medicated
# 0     NaN       True
# 1    65.0      False
# 2    66.0       True
# 3    70.0       True
# 4    52.0       True
# ..    ...        ...
# 222  71.0       True
# 223  74.0       True
# 224  64.0       True
# 225  59.0       True
# 226  66.0      False
#
# [227 rows x 9 columns]

# %%
user_data['UPDRS'] = user_data['UPDRS'].apply(lambda x: int(x) if x != 'Don\'t know' else 0)
impact_dict = {'Mild': 1, 'Medium': 2, 'Severe': 3, ' ------':0, np.nan:0}
user_data['Impact'] = user_data['Impact'].apply(lambda x: impact_dict[x]).fillna(0)
# Out:
# /var/folders/pd/jy2tczp11tvgftzcy6kn7txh0000gn/T/ipykernel_35793/1282671718.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_data['UPDRS'] = user_data['UPDRS'].apply(lambda x: int(x) if x != 'Don\'t know' else 0)
# /var/folders/pd/jy2tczp11tvgftzcy6kn7txh0000gn/T/ipykernel_35793/1282671718.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_data['Impact'] = user_data['Impact'].apply(lambda x: impact_dict[x]).fillna(0)

# %%
user_data.to_csv('user_data.csv', index=False)

# %%
data_list = glob.glob('Tappy Data/*.txt')
exp_data = []
for data in data_list:
    with open(data) as f:
        lines = f.readlines()
        for line in lines:
            line = line.strip().split('\t')
            if len(line) != 8:
                print(line)
            else:
                exp_data.append(line)
# Out:
# ['OMCPRWYBSQ', '161027', '11:38:01.707', 'R', '0085.9', 'LR', '0601.6']
# ['QAH9IVALVC', '160829', '13:33:10.324', 'L', '0078.1', 'LL', '0250.0']

# %%
exp_data = pd.DataFrame(exp_data, columns=['id','date','time','hand', 'hold_time', 'direction', 'latency', 'flight_time'])
display(exp_data)
# Out:
#                  id    date          time hand hold_time direction latency  \
# 0        0EA27ICBLF  160722  18:41:04.336    L    0101.6        LL  0234.4
# 1        0EA27ICBLF  160722  18:42:14.070    L    0085.9        LL  0437.5
# 2        0EA27ICBLF  160722  18:42:14.273    L    0078.1        LL  0210.9
# 3        0EA27ICBLF  160722  18:42:14.617    L    0062.5        LL  0359.4
# 4        0EA27ICBLF  160722  18:42:15.586    S    0125.0        LS  0187.5
# ...             ...     ...           ...  ...       ...       ...     ...
# 9316851  ZYWLN4JVLA  170126  13:56:20.117    L    0195.3        RL  0425.8
# 9316852  ZYWLN4JVLA  170126  13:56:20.242    R    0105.5        LR  0214.8
# 9316853  ZYWLN4JVLA  170126  13:56:33.625    L    0168.0        LL  0332.0
# 9316854  ZYWLN4JVLA  170126  13:56:33.836    L    0097.7        LL  0281.3
# 9316855  ZYWLN4JVLA  170126  13:56:34.066    L    0168.0        LL  0160.2
#
#         flight_time
# 0            0156.3
# 1            0359.4
# 2            0125.0
# 3            0281.3
# 4            0093.8
# ...             ...
# 9316851      0261.7
# 9316852      0019.5
# 9316853      0015.6
# 9316854      0113.3
# 9316855      0062.5
#
# [9316856 rows x 8 columns]

# %%
def process_rows(df):
    if len(df['id']) != 10:
        df['id'] = np.nan
    if len(df['hold_time']) != 6:
        df['hold_time'] = np.nan
    else:
        df['hold_time'] = float(df['hold_time'])

    if len(df['latency']) != 6:
        df['latency'] = np.nan
    else:
        df['latency'] = float(df['latency'])
    if len(df['flight_time']) != 6:
        df['flight_time'] = np.nan
    else:
        df['flight_time'] = float(df['flight_time'])
    return df

# %%
exp_data = exp_data.apply(process_rows, axis=1)

# %%
exp_data.head()
# Out:
#                  id    date          time hand  hold_time direction  latency  \
# 0        NMMGWRY6SO  170301  08:45:42.125    L      187.5        LL    421.9
# 1        NMMGWRY6SO  170301  08:45:42.422    L      203.1        LL    281.3
# 2        NMMGWRY6SO  170301  08:48:29.031    L      203.1        LL    296.9
# 3        NMMGWRY6SO  170301  08:48:29.266    L      218.8        LL    218.8
# 4        NMMGWRY6SO  170301  08:48:29.484    R      187.5        LR    250.0
# ...             ...     ...           ...  ...        ...       ...      ...
# 9316851  3HYXJCTCNT  170126  14:12:47.000    S       58.6        RS    214.8
# 9316852  3HYXJCTCNT  170126  14:12:49.422    R       85.9        LR    175.8
# 9316853  3HYXJCTCNT  170126  14:12:49.598    R       39.1        RR    222.7
# 9316854  3HYXJCTCNT  170126  14:12:51.160    L       43.0        LL    125.0
# 9316855  3HYXJCTCNT  170126  14:12:51.215    L       97.7        LL    125.0
#
#          flight_time
# 0              281.3
# 1               93.8
# 2              125.0
# 3               15.6
# 4               31.3
# ...              ...
# 9316851        160.2
# 9316852         82.0
# 9316853        136.7
# 9316854        285.2
# 9316855        285.2
#
# [9316856 rows x 8 columns]

# %%
exp_data = exp_data.dropna(axis=0)

# %%
exp_data.to_csv('typing_data.csv', index=False)

# %%
big_data = pd.merge(exp_data, user_data, on='id', how='inner')
